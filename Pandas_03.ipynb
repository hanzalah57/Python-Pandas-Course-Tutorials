# %%
import pandas as pd 
data = pd.read_csv('New_sales.csv')
data
# Out:
#       Unnamed: 0       State  Total_Expenses  Sales  Profit   Market  Trade  \
# 0              0  California            63.0  109.0  -131.0     West     40
# 1              1  California            55.0  201.0    88.0     West     24
# 2              2  California           700.0  289.0    25.0     West    109
# 3              3  California           113.0  576.0   216.0     West     81
# 4              4  California            37.0  247.0   148.0     West     26
# ...          ...         ...             ...    ...     ...      ...    ...
# 4224        4236   Wisconsin            34.0   90.0    20.0  Central     11
# 4225        4237   Wisconsin            36.0  113.0    31.0  Central     14
# 4226        4238   Wisconsin            86.0  150.0     1.0  Central     57
# 4227        4239   Wisconsin            79.0  131.0    -3.0  Central     49
# 4228        4240   Wisconsin            87.0  165.0     4.0  Central     58
#
#      Product_Type  Inventory     Type  New_Column
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0       State  Total_Expenses  Sales  Profit Market  Trade  \
# 0           0  California            63.0  109.0  -131.0   West     40
# 1           1  California            55.0  201.0    88.0   West     24
# 2           2  California           700.0  289.0    25.0   West    109
# 3           3  California           113.0  576.0   216.0   West     81
# 4           4  California            37.0  247.0   148.0   West     26
# 5           5  California            99.0  582.0   291.0   West     77
# 6           6  California            25.0   90.0    26.0   West     12
# 7           7  California            43.0  276.0   120.0   West     31
# 8           8  California            32.0  187.0    79.0   West     21
# 9           9  California           142.0  687.0   364.0   West     90
#
#   Product_Type  Inventory     Type  New_Column
# 0       Coffee     2947.0  Regular       172.0
# 1          Tea      659.0  Regular       256.0
# ...

# %%
data.iloc[4]
# Out:
# Unnamed: 0                 4
# State             California
# Total_Expenses          37.0
# Sales                  247.0
# Profit                 148.0
# Market                  West
# Trade                     26
# Product_Type      Herbal Tea
# Inventory              809.0
# Type                   Decaf
# New_Column             284.0
# Name: 4, dtype: object

# %%
data1 = pd.read_csv('New_sales.csv', index_col='State')
data1
# Out:
#             Unnamed: 0  Total_Expenses  Sales  Profit   Market  Trade  \
# State
# California           0            63.0  109.0  -131.0     West     40
# California           1            55.0  201.0    88.0     West     24
# California           2           700.0  289.0    25.0     West    109
# California           3           113.0  576.0   216.0     West     81
# California           4            37.0  247.0   148.0     West     26
# ...                ...             ...    ...     ...      ...    ...
# Wisconsin         4236            34.0   90.0    20.0  Central     11
# Wisconsin         4237            36.0  113.0    31.0  Central     14
# Wisconsin         4238            86.0  150.0     1.0  Central     57
# Wisconsin         4239            79.0  131.0    -3.0  Central     49
# Wisconsin         4240            87.0  165.0     4.0  Central     58
#
#            Product_Type  Inventory     Type  New_Column
# State
# ...

# %%
data1.loc['California']
# Out:
#             Unnamed: 0  Total_Expenses  Sales  Profit Market  Trade  \
# State
# California           0            63.0  109.0  -131.0   West     40
# California           1            55.0  201.0    88.0   West     24
# California           2           700.0  289.0    25.0   West    109
# California           3           113.0  576.0   216.0   West     81
# California           4            37.0  247.0   148.0   West     26
# ...                ...             ...    ...     ...    ...    ...
# California         276            31.0  132.0    43.0   West     19
# California         277            36.0  238.0   142.0   West     25
# California         278            40.0  274.0   166.0   West     31
# California         279            33.0  198.0    84.0   West     22
# California         280            83.0  451.0   191.0   West     59
#
#            Product_Type  Inventory     Type  New_Column
# State
# California       Coffee     2947.0  Regular       172.0
# ...

# %%
data1.loc['Colorado']
# Out:
#           Unnamed: 0  Total_Expenses  Sales  Profit   Market  Trade  \
# State
# Colorado         281            39.0  243.0   105.0  Central     27
# Colorado         282            36.0  227.0   134.0  Central     24
# Colorado         283            45.0  322.0   199.0  Central     34
# Colorado         284            39.0  190.0    68.0  Central     27
# Colorado         285            39.0  202.0   101.0  Central     27
# ...              ...             ...    ...     ...      ...    ...
# Colorado         540            34.0   91.0    16.0  Central     12
# Colorado         541            40.0  145.0    50.0  Central     19
# Colorado         542            41.0  144.0    47.0  Central     19
# Colorado         543            37.0  126.0    40.0  Central     16
# Colorado         544            37.0  124.0    39.0  Central     16
#
#          Product_Type  Inventory     Type  New_Column
# State
# Colorado       Coffee      766.0  Regular       282.0
# ...

# %%
new_data = data1.head()
new_data
# Out:
#             Unnamed: 0  Total_Expenses  Sales  Profit Market  Trade  \
# State
# California           0            63.0  109.0  -131.0   West     40
# California           1            55.0  201.0    88.0   West     24
# California           2           700.0  289.0    25.0   West    109
# California           3           113.0  576.0   216.0   West     81
# California           4            37.0  247.0   148.0   West     26
#
#            Product_Type  Inventory     Type  New_Column
# State
# California       Coffee     2947.0  Regular       172.0
# California          Tea      659.0  Regular       256.0
# California     Espresso      788.0  Regular       989.0
# California     Espresso     1744.0    Decaf       689.0
# California   Herbal Tea      809.0    Decaf       284.0

# %%
indexes = ['One', 'Two', 'Three', 'Four', 'Five']
new_data.set_index([indexes], inplace=True)
new_data
# Out:
#        Unnamed: 0  Total_Expenses  Sales  Profit Market  Trade Product_Type  \
# One             0            63.0  109.0  -131.0   West     40       Coffee
# Two             1            55.0  201.0    88.0   West     24          Tea
# Three           2           700.0  289.0    25.0   West    109     Espresso
# Four            3           113.0  576.0   216.0   West     81     Espresso
# Five            4            37.0  247.0   148.0   West     26   Herbal Tea
#
#        Inventory     Type  New_Column
# One       2947.0  Regular       172.0
# Two        659.0  Regular       256.0
# Three      788.0  Regular       989.0
# Four      1744.0    Decaf       689.0
# Five       809.0    Decaf       284.0

# %%
new_data.loc['Two']
# Out:
# Unnamed: 0              1
# Total_Expenses       55.0
# Sales               201.0
# Profit               88.0
# Market               West
# Trade                  24
# Product_Type          Tea
# Inventory           659.0
# Type              Regular
# New_Column          256.0
# Name: Two, dtype: object

# %%
new_data.loc['Three']
# Out:
# Unnamed: 0               2
# Total_Expenses       700.0
# Sales                289.0
# Profit                25.0
# Market                West
# Trade                  109
# Product_Type      Espresso
# Inventory            788.0
# Type               Regular
# New_Column           989.0
# Name: Three, dtype: object

# %%
type(new_data.loc['Three'])
# Out:
# pandas.core.series.Series
